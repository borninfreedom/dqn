# %%
import gym
import random
import math
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import matplotlib.pyplot as plt
from moviepy.editor import ImageSequenceClip

# hyper parameters
EPISODES = 1000  # number of episodes
EPS_START = 0.9  # e-greedy threshold start value
EPS_END = 0.05  # e-greedy threshold end value
EPS_DECAY = 200  # e-greedy threshold decay
GAMMA = 0.75  # Q-learning discount factor
LR = 0.001  # NN optimizer learning rate
HIDDEN_LAYER = 164  # NN hidden layer size
BATCH_SIZE = 64  # Q-learning batch size

# if gpu is to be used
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
Tensor = FloatTensor


class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []

    def push(self, transition):
        self.memory.append(transition)
        if len(self.memory) > self.capacity:
            del self.memory[0]

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

class Network(nn.Module):
    def __init__(self):
        nn.Module.__init__(self)
        self.l1 = nn.Linear(4, HIDDEN_LAYER)
        self.l2 = nn.Linear(HIDDEN_LAYER, 2)

    def forward(self, x):
        x = F.relu(self.l1(x))
        x = self.l2(x)
        return x

env = gym.make('CartPole-v0').unwrapped

model = Network()
target = Network()
if use_cuda:
    model.cuda()
    target.cuda()
memory = ReplayMemory(10000)
optimizer = optim.Adam(model.parameters(), LR)
steps_done = 0
ed = []

# def plot_durations(d):
#     plt.figure(2)
#     plt.clf()
#     plt.title('Training...')
#     plt.xlabel('Episode')
#     plt.ylabel('Duration')
#     plt.plot(d)
#
#     plt.savefig('4_policy_gradient_score.png')

def select_action(state, train=True):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if train:
        if sample > eps_threshold:
            return model(Variable(state, volatile=True).type(FloatTensor)).data.max(1)[1].view(1, 1)
        else:
            return LongTensor([[random.randrange(2)]])
    else:
        return model(Variable(state, volatile=True).type(FloatTensor)).data.max(1)[1].view(1, 1)

def run_episode(episode, env):
    state = env.reset()
    steps = 0
    while True:
        # env.render()
        action = select_action(FloatTensor([state]))
        next_state, reward, done, _ = env.step(action[0, 0].item())

        # negative reward when attempt ends
        if done:
            if steps < 30:
                reward -= 10
            else:
                reward = -1
        if steps > 100:
            reward += 1
        if steps > 200:
            reward += 1
        if steps > 300:
            reward += 1

        memory.push((FloatTensor([state]),
                     action,  # action is already a tensor
                     FloatTensor([next_state]),
                     FloatTensor([reward])))

        learn()

        state = next_state
        steps += 1

        if done or steps >= 1000:
            ed.append(steps)
            print("[Episode {:>5}]  steps: {:>5}".format(episode, steps))
            if sum(ed[-10:])/10 > 800:
                return True
            break
    return False

def learn():
    if len(memory) < BATCH_SIZE:
        return

    # random transition batch is taken from experience replay memory
    transitions = memory.sample(BATCH_SIZE)
    batch_state, batch_action, batch_next_state, batch_reward = zip(*transitions)

    batch_state = Variable(torch.cat(batch_state))
    batch_action = Variable(torch.cat(batch_action))
    batch_reward = Variable(torch.cat(batch_reward))
    batch_next_state = Variable(torch.cat(batch_next_state))

    # current Q values are estimated by NN for all actions
    current_q_values = model(batch_state).gather(1, batch_action)
    # expected Q values are estimated from actions which gives maximum Q value
    max_next_q_values = target(batch_next_state).detach().max(1)[0]
    expected_q_values = batch_reward + (GAMMA * max_next_q_values)

    # loss is measured from error between current and newly expected Q values
    loss = F.smooth_l1_loss(current_q_values, expected_q_values)

    # backpropagation of loss to NN
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

def botPlay():
    state = env.reset()
    steps = 0
    frames = []
    while True:
        frame = env.render(mode='rgb_array')
        frames.append(frame)
        action = select_action(FloatTensor([state]))
        next_state, reward, done, _ = env.step(action[0, 0])

        state = next_state
        steps += 1

        if done or steps >= 1000:
            break

    clip = ImageSequenceClip(frames, fps=20)
    clip.write_gif('4_policy_gradient_play.gif', fps=20)

for e in range(EPISODES):
    complete = run_episode(e, env)

    if complete:
        print('complete...!')
        break

    if (e+1) % 5 == 0:
        mp = list(target.parameters())
        mcp = list(model.parameters())
        n = len(mp)
        for i in range(0, n):
            mp[i].data[:] = mcp[i].data[:]
# Out:
# [Episode     0]  steps:    23
# [Episode     1]  steps:    40
# [Episode     2]  steps:    12
# [Episode     3]  steps:    12
# [Episode     4]  steps:    16
# [Episode     5]  steps:    10
# [Episode     6]  steps:    12
# [Episode     7]  steps:    17
# [Episode     8]  steps:    11
# [Episode     9]  steps:    13
# [Episode    10]  steps:    17
# [Episode    11]  steps:    14
# [Episode    12]  steps:    11
# [Episode    13]  steps:    12
# [Episode    14]  steps:    11
# [Episode    15]  steps:    14
# [Episode    16]  steps:     9
# [Episode    17]  steps:    19
# [Episode    18]  steps:    12
# [Episode    19]  steps:    12
# [Episode    20]  steps:     9
# [Episode    21]  steps:     9
# [Episode    22]  steps:     9
# [Episode    23]  steps:    15
# [Episode    24]  steps:    13
# [Episode    25]  steps:    13
# [Episode    26]  steps:     9
# [Episode    27]  steps:    11
# [Episode    28]  steps:    12
# [Episode    29]  steps:    12
# [Episode    30]  steps:     9
# [Episode    31]  steps:    11
# [Episode    32]  steps:    11
# [Episode    33]  steps:    17
# [Episode    34]  steps:    11
# [Episode    35]  steps:    14
# [Episode    36]  steps:    12
# [Episode    37]  steps:    33
# [Episode    38]  steps:    13
# [Episode    39]  steps:    12
# [Episode    40]  steps:    21
# [Episode    41]  steps:    14
# [Episode    42]  steps:    16
# [Episode    43]  steps:     9
# [Episode    44]  steps:    36
# [Episode    45]  steps:    14
# [Episode    46]  steps:    10
# [Episode    47]  steps:    14
# [Episode    48]  steps:    37
# [Episode    49]  steps:    10
# [Episode    50]  steps:     9
# [Episode    51]  steps:    10
# [Episode    52]  steps:    15
# [Episode    53]  steps:    10
# [Episode    54]  steps:    16
# [Episode    55]  steps:    10
# [Episode    56]  steps:    12
# [Episode    57]  steps:    14
# [Episode    58]  steps:     9
# [Episode    59]  steps:    13
# [Episode    60]  steps:     9
# [Episode    61]  steps:     8
# [Episode    62]  steps:    13
# [Episode    63]  steps:    10
# [Episode    64]  steps:    14
# [Episode    65]  steps:    13
# [Episode    66]  steps:    29
# [Episode    67]  steps:     9
# [Episode    68]  steps:    47
# [Episode    69]  steps:    13
# [Episode    70]  steps:    10
# [Episode    71]  steps:     9
# [Episode    72]  steps:    32
# [Episode    73]  steps:    37
# [Episode    74]  steps:    12
# [Episode    75]  steps:    13
# [Episode    76]  steps:    10
# [Episode    77]  steps:    10
# [Episode    78]  steps:    17
# [Episode    79]  steps:    14
# [Episode    80]  steps:    12
# [Episode    81]  steps:    10
# [Episode    82]  steps:    29
# [Episode    83]  steps:    13
# [Episode    84]  steps:    22
# [Episode    85]  steps:    10
# [Episode    86]  steps:    11
# [Episode    87]  steps:     9
# [Episode    88]  steps:     9
# [Episode    89]  steps:    27
# [Episode    90]  steps:    34
# [Episode    91]  steps:    10
# [Episode    92]  steps:    20
# [Episode    93]  steps:    12
# [Episode    94]  steps:    16
# [Episode    95]  steps:    24
# [Episode    96]  steps:     9
# [Episode    97]  steps:    26
# [Episode    98]  steps:    15
# [Episode    99]  steps:    10
# [Episode   100]  steps:    23
# [Episode   101]  steps:    24
# [Episode   102]  steps:    14
# [Episode   103]  steps:    18
# [Episode   104]  steps:    18
# [Episode   105]  steps:    14
# [Episode   106]  steps:    10
# [Episode   107]  steps:    25
# [Episode   108]  steps:    24
# [Episode   109]  steps:     9
# [Episode   110]  steps:    16
# [Episode   111]  steps:    17
# [Episode   112]  steps:    18
# [Episode   113]  steps:    10
# [Episode   114]  steps:    10
# [Episode   115]  steps:    12
# [Episode   116]  steps:    37
# [Episode   117]  steps:    14
# [Episode   118]  steps:    10
# [Episode   119]  steps:    10
# [Episode   120]  steps:    14
# [Episode   121]  steps:    12
# [Episode   122]  steps:    13
# [Episode   123]  steps:    22
# [Episode   124]  steps:    10
# [Episode   125]  steps:    10
# [Episode   126]  steps:    12
# [Episode   127]  steps:     9
# [Episode   128]  steps:    18
# [Episode   129]  steps:    34
# [Episode   130]  steps:    90
# [Episode   131]  steps:     9
# [Episode   132]  steps:    10
# [Episode   133]  steps:    18
# [Episode   134]  steps:    25
# [Episode   135]  steps:    14
# [Episode   136]  steps:    21
# [Episode   137]  steps:     8
# [Episode   138]  steps:    39
# [Episode   139]  steps:     8
# [Episode   140]  steps:    19
# [Episode   141]  steps:    32
# [Episode   142]  steps:    11
# [Episode   143]  steps:    14
# [Episode   144]  steps:    10
# [Episode   145]  steps:    19
# [Episode   146]  steps:    10
# [Episode   147]  steps:    11
# [Episode   148]  steps:    11
# [Episode   149]  steps:    15
# [Episode   150]  steps:    14
# [Episode   151]  steps:    36
# [Episode   152]  steps:    37
# [Episode   153]  steps:     9
# [Episode   154]  steps:    15
# [Episode   155]  steps:    21
# [Episode   156]  steps:    14
# [Episode   157]  steps:    15
# [Episode   158]  steps:     9
# [Episode   159]  steps:    10
# [Episode   160]  steps:    12
# [Episode   161]  steps:    12
# [Episode   162]  steps:    10
# [Episode   163]  steps:    20
# [Episode   164]  steps:    20
# [Episode   165]  steps:    14
# [Episode   166]  steps:    19
# [Episode   167]  steps:    11
# [Episode   168]  steps:    11
# [Episode   169]  steps:    14
# [Episode   170]  steps:     9
# [Episode   171]  steps:    10
# [Episode   172]  steps:    21
# [Episode   173]  steps:    21
# [Episode   174]  steps:    13
# [Episode   175]  steps:    18
# [Episode   176]  steps:    24
# [Episode   177]  steps:    20
# [Episode   178]  steps:    12
# [Episode   179]  steps:    12
# [Episode   180]  steps:     9
# [Episode   181]  steps:    37
# [Episode   182]  steps:    13
# [Episode   183]  steps:    14
# [Episode   184]  steps:    17
# [Episode   185]  steps:    19
# [Episode   186]  steps:    10
# [Episode   187]  steps:    17
# [Episode   188]  steps:    12
# [Episode   189]  steps:    11
# [Episode   190]  steps:    10
# [Episode   191]  steps:     9
# [Episode   192]  steps:    12
# [Episode   193]  steps:    10
# [Episode   194]  steps:    12
# [Episode   195]  steps:    25
# [Episode   196]  steps:    19
# [Episode   197]  steps:    43
# [Episode   198]  steps:    10
# [Episode   199]  steps:    25
# [Episode   200]  steps:     9
# [Episode   201]  steps:    10
# [Episode   202]  steps:    13
# [Episode   203]  steps:    11
# [Episode   204]  steps:    16
# [Episode   205]  steps:    13
# [Episode   206]  steps:    22
# [Episode   207]  steps:    12
# [Episode   208]  steps:    12
# [Episode   209]  steps:    46
# [Episode   210]  steps:    11
# [Episode   211]  steps:    14
# [Episode   212]  steps:     9
# [Episode   213]  steps:    10
# [Episode   214]  steps:    11
# [Episode   215]  steps:     9
# [Episode   216]  steps:    12
# [Episode   217]  steps:    31
# [Episode   218]  steps:    15
# [Episode   219]  steps:    10
# [Episode   220]  steps:    47
# [Episode   221]  steps:    26
# [Episode   222]  steps:    35
# [Episode   223]  steps:    14
# [Episode   224]  steps:    11
# [Episode   225]  steps:    16
# [Episode   226]  steps:    17
# [Episode   227]  steps:     9
# [Episode   228]  steps:     9
# [Episode   229]  steps:   117
# [Episode   230]  steps:    17
# [Episode   231]  steps:    23
# [Episode   232]  steps:    10
# [Episode   233]  steps:    45
# [Episode   234]  steps:    12
# [Episode   235]  steps:     9
# [Episode   236]  steps:    12
# [Episode   237]  steps:    33
# [Episode   238]  steps:    11
# [Episode   239]  steps:    17
# [Episode   240]  steps:    23
# [Episode   241]  steps:    20
# [Episode   242]  steps:    20
# [Episode   243]  steps:    31
# [Episode   244]  steps:     9
# [Episode   245]  steps:    14
# [Episode   246]  steps:    18
# [Episode   247]  steps:    22
# [Episode   248]  steps:    15
# [Episode   249]  steps:    11
# [Episode   250]  steps:    10
# [Episode   251]  steps:     9
# [Episode   252]  steps:    12
# [Episode   253]  steps:    15
# [Episode   254]  steps:    16
# [Episode   255]  steps:    11
# [Episode   256]  steps:    42
# [Episode   257]  steps:    13
# [Episode   258]  steps:    28
# [Episode   259]  steps:     9
# [Episode   260]  steps:    10
# [Episode   261]  steps:    10
# [Episode   262]  steps:    40
# [Episode   263]  steps:    10
# [Episode   264]  steps:    14
# [Episode   265]  steps:    11
# [Episode   266]  steps:    19
# [Episode   267]  steps:    10
# [Episode   268]  steps:     9
# [Episode   269]  steps:     9
# [Episode   270]  steps:    10
# [Episode   271]  steps:     8
# [Episode   272]  steps:     8
# [Episode   273]  steps:    12
# [Episode   274]  steps:    20
# [Episode   275]  steps:     9
# [Episode   276]  steps:    33
# [Episode   277]  steps:    29
# [Episode   278]  steps:    20
# [Episode   279]  steps:    27
# [Episode   280]  steps:    24
# [Episode   281]  steps:    29
# [Episode   282]  steps:    27
# [Episode   283]  steps:    16
# [Episode   284]  steps:    12
# [Episode   285]  steps:    23
# [Episode   286]  steps:    21
# [Episode   287]  steps:    12
# [Episode   288]  steps:    31
# [Episode   289]  steps:    13
# [Episode   290]  steps:    10
# [Episode   291]  steps:     9
# [Episode   292]  steps:    22
# [Episode   293]  steps:    10
# [Episode   294]  steps:     9
# [Episode   295]  steps:    15
# [Episode   296]  steps:    28
# [Episode   297]  steps:    23
# [Episode   298]  steps:    21
# [Episode   299]  steps:    13
# [Episode   300]  steps:    10
# [Episode   301]  steps:    72
# [Episode   302]  steps:    33
# [Episode   303]  steps:    10
# [Episode   304]  steps:    27
# [Episode   305]  steps:    21
# [Episode   306]  steps:    12
# [Episode   307]  steps:    12
# [Episode   308]  steps:    10
# [Episode   309]  steps:    41
# [Episode   310]  steps:     9
# [Episode   311]  steps:    11
# [Episode   312]  steps:    10
# [Episode   313]  steps:     9
# [Episode   314]  steps:    25
# [Episode   315]  steps:     9
# [Episode   316]  steps:    13
# [Episode   317]  steps:    44
# [Episode   318]  steps:    13
# [Episode   319]  steps:    10
# [Episode   320]  steps:     9
# [Episode   321]  steps:    11
# [Episode   322]  steps:    12
# [Episode   323]  steps:    10
# [Episode   324]  steps:     9
# [Episode   325]  steps:    25
# [Episode   326]  steps:    10
# [Episode   327]  steps:    19
# [Episode   328]  steps:     9
# [Episode   329]  steps:    37
# [Episode   330]  steps:    25
# [Episode   331]  steps:    23
# [Episode   332]  steps:    30
# [Episode   333]  steps:     9
# [Episode   334]  steps:     9
# [Episode   335]  steps:    12
# [Episode   336]  steps:    11
# [Episode   337]  steps:     9
# [Episode   338]  steps:     9
# [Episode   339]  steps:    19
# [Episode   340]  steps:    11
# [Episode   341]  steps:    12
# [Episode   342]  steps:    11
# [Episode   343]  steps:    10
# [Episode   344]  steps:     9
# [Episode   345]  steps:     8
# [Episode   346]  steps:     8
# [Episode   347]  steps:    16
# [Episode   348]  steps:    13
# [Episode   349]  steps:    31
# [Episode   350]  steps:     8
# [Episode   351]  steps:     9
# [Episode   352]  steps:    26
# [Episode   353]  steps:    16
# [Episode   354]  steps:    19
# [Episode   355]  steps:     9
# [Episode   356]  steps:    10
# [Episode   357]  steps:    11
# [Episode   358]  steps:    53
# [Episode   359]  steps:    25
# [Episode   360]  steps:    13
# [Episode   361]  steps:    29
# [Episode   362]  steps:     9
# [Episode   363]  steps:    10
# [Episode   364]  steps:    10
# [Episode   365]  steps:    10
# [Episode   366]  steps:     9
# [Episode   367]  steps:     9
# [Episode   368]  steps:    13
# [Episode   369]  steps:    21
# [Episode   370]  steps:    31
# [Episode   371]  steps:    16
# [Episode   372]  steps:    13
# [Episode   373]  steps:    12
# [Episode   374]  steps:    15
# [Episode   375]  steps:    11
# [Episode   376]  steps:    23
# [Episode   377]  steps:     8
# [Episode   378]  steps:    36
# [Episode   379]  steps:     9
# [Episode   380]  steps:    16
# [Episode   381]  steps:    16
# [Episode   382]  steps:    12
# [Episode   383]  steps:    41
# [Episode   384]  steps:    10
# [Episode   385]  steps:    17
# [Episode   386]  steps:    32
# [Episode   387]  steps:    15
# [Episode   388]  steps:    15
# [Episode   389]  steps:    12
# [Episode   390]  steps:    12
# [Episode   391]  steps:    16
# [Episode   392]  steps:    22
# [Episode   393]  steps:    18
# [Episode   394]  steps:    10
# [Episode   395]  steps:    10
# [Episode   396]  steps:    23
# [Episode   397]  steps:    10
# [Episode   398]  steps:    20
# [Episode   399]  steps:    33
# [Episode   400]  steps:    24
# [Episode   401]  steps:    14
# [Episode   402]  steps:    14
# [Episode   403]  steps:    31
# [Episode   404]  steps:    11
# [Episode   405]  steps:    21
# [Episode   406]  steps:    11
# [Episode   407]  steps:     8
# [Episode   408]  steps:    10
# [Episode   409]  steps:    42
# [Episode   410]  steps:    15
# [Episode   411]  steps:    11
# [Episode   412]  steps:    10
# [Episode   413]  steps:    14
# [Episode   414]  steps:    12
# [Episode   415]  steps:    10
# [Episode   416]  steps:    22
# [Episode   417]  steps:     9
# [Episode   418]  steps:    11
# [Episode   419]  steps:     9
# [Episode   420]  steps:    11
# [Episode   421]  steps:    14
# [Episode   422]  steps:     9
# [Episode   423]  steps:    15
# [Episode   424]  steps:    19
# [Episode   425]  steps:    10
# [Episode   426]  steps:     9
# [Episode   427]  steps:    16
# [Episode   428]  steps:    10
# [Episode   429]  steps:     8
# [Episode   430]  steps:    22
# [Episode   431]  steps:    10
# [Episode   432]  steps:    31
# [Episode   433]  steps:    11
# [Episode   434]  steps:    21
# [Episode   435]  steps:    11
# [Episode   436]  steps:    10
# [Episode   437]  steps:     9
# [Episode   438]  steps:    10
# [Episode   439]  steps:     8
# [Episode   440]  steps:    26
# [Episode   441]  steps:    15
# [Episode   442]  steps:    25
# [Episode   443]  steps:    24
# [Episode   444]  steps:    10
# [Episode   445]  steps:    22
# [Episode   446]  steps:    23
# [Episode   447]  steps:    20
# [Episode   448]  steps:    35
# [Episode   449]  steps:    10
# [Episode   450]  steps:    48
# [Episode   451]  steps:    11
# [Episode   452]  steps:    15
# [Episode   453]  steps:    32
# [Episode   454]  steps:    14
# [Episode   455]  steps:    12
# [Episode   456]  steps:    10
# [Episode   457]  steps:     8
# [Episode   458]  steps:    32
# [Episode   459]  steps:    10
# [Episode   460]  steps:    10
# [Episode   461]  steps:     9
# [Episode   462]  steps:    13
# [Episode   463]  steps:     8
# [Episode   464]  steps:    20
# [Episode   465]  steps:    17
# [Episode   466]  steps:    10
# [Episode   467]  steps:    21
# [Episode   468]  steps:    19
# [Episode   469]  steps:    13
# [Episode   470]  steps:     9
# [Episode   471]  steps:     9
# [Episode   472]  steps:     9
# [Episode   473]  steps:    15
# [Episode   474]  steps:    10
# [Episode   475]  steps:    35
# [Episode   476]  steps:    63
# [Episode   477]  steps:    17
# [Episode   478]  steps:    15
# [Episode   479]  steps:    24
# [Episode   480]  steps:    25
# [Episode   481]  steps:    11
# [Episode   482]  steps:    10
# [Episode   483]  steps:    62
# [Episode   484]  steps:    18
# [Episode   485]  steps:     9
# [Episode   486]  steps:    30
# [Episode   487]  steps:    39
# [Episode   488]  steps:    20
# [Episode   489]  steps:    41
# [Episode   490]  steps:    58
# [Episode   491]  steps:     9
# [Episode   492]  steps:    20
# [Episode   493]  steps:    10
# [Episode   494]  steps:    35
# [Episode   495]  steps:    26
# [Episode   496]  steps:    35
# [Episode   497]  steps:    18
# [Episode   498]  steps:    15
# [Episode   499]  steps:     9
# [Episode   500]  steps:     8
# [Episode   501]  steps:    15
# [Episode   502]  steps:    10
# [Episode   503]  steps:    12
# [Episode   504]  steps:    55
# [Episode   505]  steps:    10
# [Episode   506]  steps:    15
# [Episode   507]  steps:    36
# [Episode   508]  steps:     9
# [Episode   509]  steps:    10
# [Episode   510]  steps:    20
# [Episode   511]  steps:    10
# [Episode   512]  steps:    11
# [Episode   513]  steps:    11
# [Episode   514]  steps:    22
# [Episode   515]  steps:    11
# [Episode   516]  steps:    10
# [Episode   517]  steps:    10
# [Episode   518]  steps:    14
# [Episode   519]  steps:     9
# [Episode   520]  steps:    12
# [Episode   521]  steps:    11
# [Episode   522]  steps:     9
# [Episode   523]  steps:    15
# [Episode   524]  steps:    10
# [Episode   525]  steps:    24
# [Episode   526]  steps:    10
# [Episode   527]  steps:    10
# [Episode   528]  steps:    12
# [Episode   529]  steps:     9
# [Episode   530]  steps:    10
# [Episode   531]  steps:    33
# [Episode   532]  steps:    21
# [Episode   533]  steps:    12
# [Episode   534]  steps:    16
# [Episode   535]  steps:    10
# [Episode   536]  steps:    10
# [Episode   537]  steps:    39
# [Episode   538]  steps:    27
# [Episode   539]  steps:     9
# [Episode   540]  steps:    34
# [Episode   541]  steps:    15
# [Episode   542]  steps:    49
# [Episode   543]  steps:     9
# [Episode   544]  steps:    12
# [Episode   545]  steps:    11
# [Episode   546]  steps:    11
# [Episode   547]  steps:    10
# [Episode   548]  steps:    13
# [Episode   549]  steps:    20
# [Episode   550]  steps:    14
# [Episode   551]  steps:    13
# [Episode   552]  steps:    13
# [Episode   553]  steps:    35
# [Episode   554]  steps:    23
# [Episode   555]  steps:    24
# [Episode   556]  steps:    11
# [Episode   557]  steps:     9
# [Episode   558]  steps:    11
# [Episode   559]  steps:    11
# [Episode   560]  steps:    13
# [Episode   561]  steps:    28
# [Episode   562]  steps:    12
# [Episode   563]  steps:    15
# [Episode   564]  steps:    26
# [Episode   565]  steps:    23
# [Episode   566]  steps:    17
# [Episode   567]  steps:    21
# [Episode   568]  steps:    12
# [Episode   569]  steps:     8
# [Episode   570]  steps:     8
# [Episode   571]  steps:    23
# [Episode   572]  steps:     8
# [Episode   573]  steps:    24
# [Episode   574]  steps:    10
# [Episode   575]  steps:    29
# [Episode   576]  steps:    24
# [Episode   577]  steps:    20
# [Episode   578]  steps:    10
# [Episode   579]  steps:    12
# [Episode   580]  steps:    10
# [Episode   581]  steps:    11
# [Episode   582]  steps:    11
# [Episode   583]  steps:    12
# [Episode   584]  steps:     8
# [Episode   585]  steps:    10
# [Episode   586]  steps:     8
# [Episode   587]  steps:     9
# [Episode   588]  steps:    16
# [Episode   589]  steps:     8
# [Episode   590]  steps:    32
# [Episode   591]  steps:    37
# [Episode   592]  steps:     9
# [Episode   593]  steps:     9
# [Episode   594]  steps:     8
# [Episode   595]  steps:    10
# [Episode   596]  steps:    21
# [Episode   597]  steps:    24
# [Episode   598]  steps:    35
# [Episode   599]  steps:     9
# [Episode   600]  steps:    11
# [Episode   601]  steps:    10
# [Episode   602]  steps:    13
# [Episode   603]  steps:     9
# [Episode   604]  steps:    22
# [Episode   605]  steps:    10
# [Episode   606]  steps:    13
# [Episode   607]  steps:    12
# [Episode   608]  steps:    17
# [Episode   609]  steps:    12
# [Episode   610]  steps:    16
# [Episode   611]  steps:    48
# [Episode   612]  steps:    12
# [Episode   613]  steps:    15
# [Episode   614]  steps:    28
# [Episode   615]  steps:    10
# [Episode   616]  steps:    13
# [Episode   617]  steps:     9
# [Episode   618]  steps:    10
# [Episode   619]  steps:    17
# [Episode   620]  steps:    12
# [Episode   621]  steps:    12
# [Episode   622]  steps:    10
# [Episode   623]  steps:    14
# [Episode   624]  steps:    10
# [Episode   625]  steps:    12
# [Episode   626]  steps:    10
# [Episode   627]  steps:    11
# [Episode   628]  steps:    10
# [Episode   629]  steps:    11
# [Episode   630]  steps:     9
# [Episode   631]  steps:    16
# [Episode   632]  steps:     8
# [Episode   633]  steps:     9
# [Episode   634]  steps:    43
# [Episode   635]  steps:    11
# [Episode   636]  steps:    12
# [Episode   637]  steps:     8
# [Episode   638]  steps:    10
# [Episode   639]  steps:    33
# [Episode   640]  steps:    18
# [Episode   641]  steps:    10
# [Episode   642]  steps:    22
# [Episode   643]  steps:    10
# [Episode   644]  steps:    15
# [Episode   645]  steps:    18
# [Episode   646]  steps:    10
# [Episode   647]  steps:    10
# [Episode   648]  steps:    13
# [Episode   649]  steps:    10
# [Episode   650]  steps:     9
# [Episode   651]  steps:    25
# [Episode   652]  steps:    27
# [Episode   653]  steps:     8
# [Episode   654]  steps:    14
# [Episode   655]  steps:    10
# [Episode   656]  steps:    25
# [Episode   657]  steps:    17
# [Episode   658]  steps:    22
# [Episode   659]  steps:    20
# [Episode   660]  steps:    28
# [Episode   661]  steps:    14
# [Episode   662]  steps:    32
# [Episode   663]  steps:    15
# [Episode   664]  steps:    22
# [Episode   665]  steps:     9
# [Episode   666]  steps:     9
# [Episode   667]  steps:    12
# [Episode   668]  steps:    10
# [Episode   669]  steps:    15
# [Episode   670]  steps:    20
# [Episode   671]  steps:    13
# [Episode   672]  steps:     9
# [Episode   673]  steps:    10
# [Episode   674]  steps:     9
# [Episode   675]  steps:    18
# [Episode   676]  steps:     9
# [Episode   677]  steps:    39
# [Episode   678]  steps:    11
# [Episode   679]  steps:    10
# [Episode   680]  steps:    29
# [Episode   681]  steps:    10
# [Episode   682]  steps:     9
# [Episode   683]  steps:    16
# [Episode   684]  steps:    10
# [Episode   685]  steps:    11
# [Episode   686]  steps:    13
# [Episode   687]  steps:    14
# [Episode   688]  steps:    30
# [Episode   689]  steps:     8
# [Episode   690]  steps:    26
# [Episode   691]  steps:    15
# [Episode   692]  steps:     9
# [Episode   693]  steps:    13
# [Episode   694]  steps:    16
# [Episode   695]  steps:    15
# [Episode   696]  steps:     8
# [Episode   697]  steps:    10
# [Episode   698]  steps:    11
# [Episode   699]  steps:    13
# [Episode   700]  steps:    23
# [Episode   701]  steps:    33
# [Episode   702]  steps:    10
# [Episode   703]  steps:    14
# [Episode   704]  steps:    36
# [Episode   705]  steps:     9
# [Episode   706]  steps:    33
# [Episode   707]  steps:    10
# [Episode   708]  steps:    14
# [Episode   709]  steps:    11
# [Episode   710]  steps:    18
# [Episode   711]  steps:    10
# [Episode   712]  steps:     9
# [Episode   713]  steps:    19
# [Episode   714]  steps:    31
# [Episode   715]  steps:    16
# [Episode   716]  steps:     9
# [Episode   717]  steps:    31
# [Episode   718]  steps:    29
# [Episode   719]  steps:    18
# [Episode   720]  steps:     9
# [Episode   721]  steps:    18
# [Episode   722]  steps:    10
# [Episode   723]  steps:    11
# [Episode   724]  steps:    10
# [Episode   725]  steps:    16
# [Episode   726]  steps:    33
# [Episode   727]  steps:    13
# [Episode   728]  steps:    11
# [Episode   729]  steps:    22
# [Episode   730]  steps:    10
# [Episode   731]  steps:    28
# [Episode   732]  steps:    24
# [Episode   733]  steps:    10
# [Episode   734]  steps:     8
# [Episode   735]  steps:     9
# [Episode   736]  steps:    10
# [Episode   737]  steps:    18
# [Episode   738]  steps:    10
# [Episode   739]  steps:    10
# [Episode   740]  steps:    32
# [Episode   741]  steps:    14
# [Episode   742]  steps:     8
# [Episode   743]  steps:    10
# [Episode   744]  steps:    16
# [Episode   745]  steps:    29
# [Episode   746]  steps:    11
# [Episode   747]  steps:    33
# [Episode   748]  steps:    14
# [Episode   749]  steps:     8
# [Episode   750]  steps:    36
# [Episode   751]  steps:    11
# [Episode   752]  steps:    25
# [Episode   753]  steps:    10
# [Episode   754]  steps:    10
# [Episode   755]  steps:    17
# [Episode   756]  steps:     9
# [Episode   757]  steps:    26
# [Episode   758]  steps:    11
# [Episode   759]  steps:    18
# [Episode   760]  steps:    23
# [Episode   761]  steps:    18
# [Episode   762]  steps:    16
# [Episode   763]  steps:     8
# [Episode   764]  steps:    13
# [Episode   765]  steps:    15
# [Episode   766]  steps:    10
# [Episode   767]  steps:    15
# [Episode   768]  steps:    14
# [Episode   769]  steps:     8
# [Episode   770]  steps:    11
# [Episode   771]  steps:    26
# [Episode   772]  steps:     9
# [Episode   773]  steps:    22
# [Episode   774]  steps:    10
# [Episode   775]  steps:    34
# [Episode   776]  steps:    10
# [Episode   777]  steps:    10
# [Episode   778]  steps:    16
# [Episode   779]  steps:    13
# [Episode   780]  steps:    32
# [Episode   781]  steps:    22
# [Episode   782]  steps:    14
# [Episode   783]  steps:    26
# [Episode   784]  steps:     8
# [Episode   785]  steps:    11
# [Episode   786]  steps:    13
# [Episode   787]  steps:    18
# [Episode   788]  steps:    15
# [Episode   789]  steps:     8
# [Episode   790]  steps:     9
# [Episode   791]  steps:    16
# [Episode   792]  steps:    10
# [Episode   793]  steps:    20
# [Episode   794]  steps:     9
# [Episode   795]  steps:    14
# [Episode   796]  steps:    25
# [Episode   797]  steps:    29
# [Episode   798]  steps:    10
# [Episode   799]  steps:    14
# [Episode   800]  steps:    11
# [Episode   801]  steps:    41
# [Episode   802]  steps:    19
# [Episode   803]  steps:    19
# [Episode   804]  steps:     8
# [Episode   805]  steps:    14
# [Episode   806]  steps:    31
# [Episode   807]  steps:    10
# [Episode   808]  steps:     8
# [Episode   809]  steps:    12
# [Episode   810]  steps:     8
# [Episode   811]  steps:    10
# [Episode   812]  steps:     9
# [Episode   813]  steps:    11
# [Episode   814]  steps:    43
# [Episode   815]  steps:    10
# [Episode   816]  steps:    11
# [Episode   817]  steps:     9
# [Episode   818]  steps:    14
# [Episode   819]  steps:    17
# [Episode   820]  steps:    22
# [Episode   821]  steps:     9
# [Episode   822]  steps:     9
# [Episode   823]  steps:    11
# [Episode   824]  steps:    19
# [Episode   825]  steps:    16
# [Episode   826]  steps:    26
# [Episode   827]  steps:    17
# [Episode   828]  steps:    10
# [Episode   829]  steps:    11
# [Episode   830]  steps:    10
# [Episode   831]  steps:    10
# [Episode   832]  steps:    16
# [Episode   833]  steps:     8
# [Episode   834]  steps:     9
# [Episode   835]  steps:    21
# [Episode   836]  steps:    16
# [Episode   837]  steps:    39
# [Episode   838]  steps:    10
# [Episode   839]  steps:    24
# [Episode   840]  steps:    10
# [Episode   841]  steps:    10
# [Episode   842]  steps:     9
# [Episode   843]  steps:    10
# [Episode   844]  steps:     9
# [Episode   845]  steps:    16
# [Episode   846]  steps:    11
# [Episode   847]  steps:    10
# [Episode   848]  steps:     9
# [Episode   849]  steps:     8
# [Episode   850]  steps:    19
# [Episode   851]  steps:    15
# [Episode   852]  steps:     9
# [Episode   853]  steps:    22
# [Episode   854]  steps:    10
# [Episode   855]  steps:    28
# [Episode   856]  steps:     9
# [Episode   857]  steps:    10
# [Episode   858]  steps:    13
# [Episode   859]  steps:     9
# [Episode   860]  steps:    19
# [Episode   861]  steps:    11
# [Episode   862]  steps:    12
# [Episode   863]  steps:    10
# [Episode   864]  steps:    15
# [Episode   865]  steps:    10
# [Episode   866]  steps:    35
# [Episode   867]  steps:    17
# [Episode   868]  steps:    10
# [Episode   869]  steps:     9
# [Episode   870]  steps:    10
# [Episode   871]  steps:    12
# [Episode   872]  steps:    16
# [Episode   873]  steps:    26
# [Episode   874]  steps:    20
# [Episode   875]  steps:    10
# [Episode   876]  steps:     9
# [Episode   877]  steps:    17
# [Episode   878]  steps:    17
# [Episode   879]  steps:    11
# [Episode   880]  steps:    14
# [Episode   881]  steps:    10
# [Episode   882]  steps:    11
# [Episode   883]  steps:    51
# [Episode   884]  steps:    17
# [Episode   885]  steps:    14
# [Episode   886]  steps:    13
# [Episode   887]  steps:     9
# [Episode   888]  steps:    16
# [Episode   889]  steps:     9
# [Episode   890]  steps:    10
# [Episode   891]  steps:    15
# [Episode   892]  steps:    44
# [Episode   893]  steps:     9
# [Episode   894]  steps:    18
# [Episode   895]  steps:     9
# [Episode   896]  steps:    21
# [Episode   897]  steps:    16
# [Episode   898]  steps:     8
# [Episode   899]  steps:    10
# [Episode   900]  steps:     9
# [Episode   901]  steps:    15
# [Episode   902]  steps:    12
# [Episode   903]  steps:     9
# [Episode   904]  steps:    15
# [Episode   905]  steps:    20
# [Episode   906]  steps:    16
# [Episode   907]  steps:     9
# [Episode   908]  steps:     8
# [Episode   909]  steps:    10
# [Episode   910]  steps:     9
# [Episode   911]  steps:    24
# [Episode   912]  steps:     9
# [Episode   913]  steps:     9
# [Episode   914]  steps:    15
# [Episode   915]  steps:    14
# [Episode   916]  steps:    16
# [Episode   917]  steps:    12
# [Episode   918]  steps:    18
# [Episode   919]  steps:    11
# [Episode   920]  steps:     9
# [Episode   921]  steps:    20
# [Episode   922]  steps:     9
# [Episode   923]  steps:     9
# [Episode   924]  steps:     9
# [Episode   925]  steps:    12
# [Episode   926]  steps:    10
# [Episode   927]  steps:     8
# [Episode   928]  steps:    12
# [Episode   929]  steps:    12
# [Episode   930]  steps:    10
# [Episode   931]  steps:     9
# [Episode   932]  steps:    12
# [Episode   933]  steps:    14
# [Episode   934]  steps:     9
# [Episode   935]  steps:    16
# [Episode   936]  steps:    14
# [Episode   937]  steps:    11
# [Episode   938]  steps:     8
# [Episode   939]  steps:    19
# [Episode   940]  steps:    19
# [Episode   941]  steps:    10
# [Episode   942]  steps:    14
# [Episode   943]  steps:    38
# [Episode   944]  steps:     9
# [Episode   945]  steps:    10
# [Episode   946]  steps:    11
# [Episode   947]  steps:    23
# [Episode   948]  steps:    19
# [Episode   949]  steps:    11
# [Episode   950]  steps:    12
# [Episode   951]  steps:     9
# [Episode   952]  steps:    11
# [Episode   953]  steps:    17
# [Episode   954]  steps:    10
# [Episode   955]  steps:     9
# [Episode   956]  steps:    13
# [Episode   957]  steps:    25
# [Episode   958]  steps:    22
# [Episode   959]  steps:     9
# [Episode   960]  steps:    16
# [Episode   961]  steps:     9
# [Episode   962]  steps:    30
# [Episode   963]  steps:     9
# [Episode   964]  steps:    11
# [Episode   965]  steps:    10
# [Episode   966]  steps:     8
# [Episode   967]  steps:    27
# [Episode   968]  steps:    17
# [Episode   969]  steps:     9
# [Episode   970]  steps:    14
# [Episode   971]  steps:    16
# [Episode   972]  steps:    13
# [Episode   973]  steps:    22
# [Episode   974]  steps:    17
# [Episode   975]  steps:    15
# [Episode   976]  steps:    10
# [Episode   977]  steps:    14
# [Episode   978]  steps:     9
# [Episode   979]  steps:    12
# [Episode   980]  steps:     9
# [Episode   981]  steps:     9
# [Episode   982]  steps:    10
# [Episode   983]  steps:    18
# [Episode   984]  steps:    14
# [Episode   985]  steps:    10
# [Episode   986]  steps:     8
# [Episode   987]  steps:    20
# [Episode   988]  steps:    21
# [Episode   989]  steps:    11
# [Episode   990]  steps:     9
# [Episode   991]  steps:    16
# [Episode   992]  steps:     9
# [Episode   993]  steps:    10
# [Episode   994]  steps:    21
# [Episode   995]  steps:    19
# [Episode   996]  steps:    17
# [Episode   997]  steps:    20
# [Episode   998]  steps:     9
# [Episode   999]  steps:    29
