# %%
#!/usr/bin/env python3

# %pip install tensorboardX 
import gym
from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim


HIDDEN_SIZE = 128
BATCH_SIZE = 16
PERCENTILE = 70


class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)


Episode = namedtuple('Episode', field_names=['reward', 'steps'])
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])


def iterate_batches(env, net, batch_size):
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs = env.reset()
    
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.FloatTensor([obs])
        act_probs_v = sm(net(obs_v))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, _ = env.step(action)
        env.render()
        episode_reward += reward
        episode_steps.append(EpisodeStep(observation=obs, action=action))
        if is_done:
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            episode_reward = 0.0
            episode_steps = []
            next_obs = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs


def filter_batch(batch, percentile):
    rewards = list(map(lambda s: s.reward, batch))
    reward_bound = np.percentile(rewards, percentile)
    reward_mean = float(np.mean(rewards))

    train_obs = []
    train_act = []
    for example in batch:
        if example.reward < reward_bound:
            continue
        train_obs.extend(map(lambda step: step.observation, example.steps))
        train_act.extend(map(lambda step: step.action, example.steps))

    train_obs_v = torch.FloatTensor(train_obs)
    train_act_v = torch.LongTensor(train_act)
    return train_obs_v, train_act_v, reward_bound, reward_mean


if __name__ == "__main__":
    env = gym.make("CartPole-v0")
    #env.render()
    # env = gym.wrappers.Monitor(env, directory="mon", force=True)
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n

    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    objective = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.01)
    writer = SummaryWriter(comment="-cartpole")

    for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
        obs_v, acts_v, reward_b, reward_m = filter_batch(batch, PERCENTILE)
        optimizer.zero_grad()
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        optimizer.step()
        print("%d: loss=%.3f, reward_mean=%.1f, reward_bound=%.1f" % (
            iter_no, loss_v.item(), reward_m, reward_b))
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_bound", reward_b, iter_no)
        writer.add_scalar("reward_mean", reward_m, iter_no)
        if reward_m > 199:
            print("Solved!")
            break
    writer.close()
# Out:
# Looking in indexes: https://pypi.douban.com/simple/
# Requirement already satisfied: tensorboardX in ./lib/python3.7/site-packages (2.1)
# Requirement already satisfied: protobuf>=3.8.0 in ./lib/python3.7/site-packages (from tensorboardX) (3.14.0)
# Requirement already satisfied: six in ./lib/python3.7/site-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: numpy in ./lib/python3.7/site-packages (from tensorboardX) (1.19.4)
# Requirement already satisfied: six in ./lib/python3.7/site-packages (from tensorboardX) (1.15.0)
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/dell/myProjects/dqn/dqn_pytorch_cartpole/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# 0: loss=0.697, reward_mean=24.1, reward_bound=23.0
# 1: loss=0.672, reward_mean=24.2, reward_bound=28.0
# 2: loss=0.658, reward_mean=42.2, reward_bound=45.5
# 3: loss=0.649, reward_mean=50.1, reward_bound=61.5
# 4: loss=0.650, reward_mean=36.9, reward_bound=45.5
# 5: loss=0.629, reward_mean=52.3, reward_bound=58.0
# 6: loss=0.636, reward_mean=43.2, reward_bound=45.0
# 7: loss=0.642, reward_mean=42.1, reward_bound=43.0
# 8: loss=0.614, reward_mean=63.1, reward_bound=76.0
# 9: loss=0.617, reward_mean=68.4, reward_bound=72.0
# 10: loss=0.590, reward_mean=62.1, reward_bound=75.5
# 11: loss=0.598, reward_mean=53.9, reward_bound=54.0
# 12: loss=0.609, reward_mean=59.7, reward_bound=61.0
# 13: loss=0.591, reward_mean=60.1, reward_bound=68.0
# 14: loss=0.574, reward_mean=69.0, reward_bound=65.5
# 15: loss=0.599, reward_mean=62.5, reward_bound=62.0
# 16: loss=0.591, reward_mean=79.8, reward_bound=97.5
# 17: loss=0.572, reward_mean=77.2, reward_bound=90.0
# 18: loss=0.570, reward_mean=76.9, reward_bound=84.0
# 19: loss=0.565, reward_mean=89.6, reward_bound=94.5
# 20: loss=0.575, reward_mean=95.2, reward_bound=104.0
# 21: loss=0.558, reward_mean=97.5, reward_bound=106.0
# 22: loss=0.561, reward_mean=123.4, reward_bound=142.5
# 23: loss=0.557, reward_mean=121.7, reward_bound=154.5
# 24: loss=0.580, reward_mean=110.6, reward_bound=118.5
# 25: loss=0.562, reward_mean=116.6, reward_bound=139.0
# 26: loss=0.550, reward_mean=110.4, reward_bound=137.5
# 27: loss=0.554, reward_mean=147.7, reward_bound=166.0
# 28: loss=0.559, reward_mean=168.6, reward_bound=198.0
# 29: loss=0.536, reward_mean=166.2, reward_bound=200.0
# 30: loss=0.560, reward_mean=182.7, reward_bound=200.0
# 31: loss=0.557, reward_mean=172.9, reward_bound=200.0
# 32: loss=0.562, reward_mean=192.8, reward_bound=200.0
# 33: loss=0.548, reward_mean=198.9, reward_bound=200.0
# 34: loss=0.548, reward_mean=168.8, reward_bound=200.0
# 35: loss=0.548, reward_mean=162.4, reward_bound=200.0
# 36: loss=0.548, reward_mean=186.6, reward_bound=200.0
# 37: loss=0.544, reward_mean=183.0, reward_bound=200.0
# 38: loss=0.542, reward_mean=177.4, reward_bound=200.0
# 39: loss=0.540, reward_mean=161.2, reward_bound=200.0
# 40: loss=0.524, reward_mean=174.8, reward_bound=200.0
# 41: loss=0.541, reward_mean=178.3, reward_bound=200.0
# 42: loss=0.540, reward_mean=181.9, reward_bound=200.0
# 43: loss=0.525, reward_mean=185.0, reward_bound=200.0
# 44: loss=0.536, reward_mean=172.1, reward_bound=200.0
# 45: loss=0.529, reward_mean=188.7, reward_bound=200.0
# 46: loss=0.527, reward_mean=196.1, reward_bound=200.0
# 47: loss=0.524, reward_mean=196.2, reward_bound=200.0
